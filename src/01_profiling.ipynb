# %%
import pandas as pd

# %%
# Load CSV file into dataframe
df = pd.read_csv("../data/raw/parks_backbone.csv")

# %%
print(df)
# Out:
#     park_id                                        park_name  \
# 0         1                       Bow Valley Provincial Park
# 1         2                   Peter Lougheed Provincial Park
# 2         3                      Sheep River Provincial Park
# 3         4          Little Elbow Provincial Recreation Area
# 4         5          Sibbald Lake Provincial Recreation Area
# 5         6           Elbow River Provincial Recreation Area
# 6         7               William A. Switzer Provincial Park
# 7         8              Pierre Grey's Lakes Provincial Park
# 8         9  Little Bow Reservoir Provincial Recreation Area
# 9        10                       Little Bow Provincial Park
# 10       11                         Dinosaur Provincial Park
# 11       12                  Gooseberry Lake Provincial Park
# 12       13                    Cypress Hills Provincial Park
# 13       14                 Writing-on-Stone Provincial Park
# ...

# %%
# Display first 5 rows of dataframe
df.head()
# Out:
#    park_id                                park_name  \
# 0        1               Bow Valley Provincial Park
# 1        2           Peter Lougheed Provincial Park
# 2        3              Sheep River Provincial Park
# 3        4  Little Elbow Provincial Recreation Area
# 4        5  Sibbald Lake Provincial Recreation Area
#
#                     park_type              region  latitude  longitude  \
# 0             Provincial Park  Kananaskis Country  51.08287 -115.10248
# 1             Provincial Park  Kananaskis Country  50.68233 -115.19612
# 2             Provincial Park  Kananaskis Country  50.63689 -114.52842
# 3  Provincial Recreation Area  Kananaskis Country  50.79278 -114.86334
# 4  Provincial Recreation Area  Kananaskis Country  51.04688 -114.86058
#
#    num_campsites  has_powered_sites  has_water  \
# 0            339               True       True
# 1            545               True       True
# 2            218               True      False
# ...

# %%
# Returns number of rows and columns
df.shape
# Out:
# (30, 10)

# %%
# Returns data type and non-null value count for each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   park_id            30 non-null     int64
#  1   park_name          30 non-null     object
#  2   park_type          30 non-null     object
#  3   region             30 non-null     object
#  4   latitude           30 non-null     float64
#  5   longitude          30 non-null     float64
#  6   num_campsites      30 non-null     int64
#  7   has_powered_sites  30 non-null     bool
#  8   has_water          30 non-null     bool
#  9   source_url         30 non-null     object
# dtypes: bool(2), float64(2), int64(2), object(4)
# memory usage: 2.1+ KB

# %%
# Calculates and displays number of null values for each column
na_sum = df.isnull().sum()
print(na_sum)
# Out:
# park_id              0
# park_name            0
# park_type            0
# region               0
# latitude             0
# longitude            0
# num_campsites        0
# has_powered_sites    0
# has_water            0
# source_url           0
# dtype: int64
